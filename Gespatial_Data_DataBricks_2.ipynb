# %%
# !pip install freeze
# !pip install geopandas
# !pip install descartes
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.DataFrame(
    {'City': ['Cuatemala City'],
     'Country': ['Guatemala'],
     'Latitude': [14.6349],
     'Longitude': [-90.5069]})
#14.6349° N, 90.5069° W
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
# City         1 non-null object
# Country      1 non-null object
# Latitude     1 non-null float64
# Longitude    1 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 112.0+ bytes
# </div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cuatemala City</td>
#       <td>Guatemala</td>
#       <td>14.6349</td>
#       <td>-90.5069</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;geopandas.geodataframe.GeoDataFrame&#39;&gt;
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
# City         1 non-null object
# Country      1 non-null object
# Latitude     1 non-null float64
# Longitude    1 non-null float64
# geometry     1 non-null geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 120.0+ bytes
# </div>

# %%
gdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cuatemala City</td>
#       <td>Guatemala</td>
#       <td>14.6349</td>
#       <td>-90.5069</td>
#       <td>POINT (-90.50690 14.63490)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
gdf = gpd.GeoDataFrame(df.drop(['Latitude', 'Longitude'], axis=1), crs={'init': 'epsg:4326'})

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

base = world.plot(color='black', edgecolor='green')

gdf.plot(ax=base, marker='o', color='red', markersize=5)

display()

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

ax = world[world.continent == 'North America'].plot(color='black', edgecolor='green')

gdf.plot(ax=ax, color='red')

display()
